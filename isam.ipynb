# %%
# All the imports we need
import numpy as np
import gtsam
from gtsam.utils.plot import plot_pose3
from matplotlib import pyplot as plt
from gtsam.symbol_shorthand import B, V, X
from gtbook.display import show
from mpl_toolkits.mplot3d import Axes3D

try:
  # For Google Colab
  from google.colab import output
  output.enable_custom_widget_manager()
  print(" -- Custom widgets enabled")
except:
  pass

# For interactive plots
# %matplotlib widget

def vector3(x, y, z):
    """Create 3d double numpy array."""
    return np.array([x, y, z], dtype=float)

# %%
T = 24  # The timespan of our trajectory.
dt = 1e-2  # 100 Hz frequency
velocity = np.array([2, 0, 0])  # The velocity we wish to move at.


scenarios = {
    "zero_twist": (np.zeros(3), np.zeros(3)),  # Zero motion, stationary trajectory.
    "forward_motion": (np.zeros(3), velocity),  # Move forward in the x axis at 2 m/s.
    "loop": (np.array([0, -np.radians(30), 0]), velocity),  # A loop-de-loop trajectory.
    "sick": (np.array([np.radians(30), -np.radians(30), 0]), velocity)  # A spiral trajectory, "sick" in surfer slang.
}


def plot_scenario(scenario,
                  T,
                  dt,
                  title="IMU trajectory scenario",
                  fignum=0,
                  maxDim=5):
    for t in np.arange(0, T, dt):
        actualPose = scenario.pose(t)
        plot_pose3(fignum, actualPose, axis_length=0.3)

        translation = actualPose.translation()
        maxDim = max([max(np.abs(translation)), maxDim])
        ax = plt.gca()
        ax.set_xlim3d(-maxDim, maxDim)
        ax.set_ylim3d(-maxDim, maxDim)
        ax.set_zlim3d(-maxDim, maxDim)
        ax.set_title(title)
    

    plt.show()

# %%
scenario = gtsam.ConstantTwistScenario(*scenarios["forward_motion"])

# %%
accBias = np.array([-0.3, 0.1, 0.2])
gyroBias = np.array([0.1, 0.3, -0.1])
# accBias = np.array([-0.0, 0.0, 0.0])
# gyroBias = np.array([0.0, 0.0, -0.0])
actualBias = gtsam.imuBias.ConstantBias(accBias, gyroBias)

pim_params = gtsam.PreintegrationParams.MakeSharedU(9.81)

# Some arbitrary noise sigmas
gyro_sigma = 1e-3
accel_sigma = 1e-3
I_3x3 = np.eye(3)
pim_params.setGyroscopeCovariance(gyro_sigma**2 * I_3x3)
pim_params.setAccelerometerCovariance(accel_sigma**2 * I_3x3)
pim_params.setIntegrationCovariance(1e-7**2 * I_3x3)
g = 9.81
n_gravity = vector3(0, 0, -g)

BIAS_COVARIANCE = gtsam.noiseModel.Isotropic.Variance(6, 0.1)

# Define the PreintegratedImuMeasurements object here.
pim = gtsam.PreintegratedImuMeasurements(pim_params, actualBias)

runner = gtsam.ScenarioRunner(scenario, pim_params, dt, actualBias)
# plot_scenario(scenario, T, dt, fignum=6)

# %%
isam = gtsam.ISAM2()
graph = gtsam.NonlinearFactorGraph()
initial = gtsam.Values()

# %%
def add_priors(scenario, graph, initial, isam):
    # Noise models for
    priorNoise = gtsam.noiseModel.Isotropic.Sigma(6, 0.1)
    velNoise = gtsam.noiseModel.Isotropic.Sigma(3, 0.1)

    initial_state = scenario.navState(0)
    graph.push_back(
        gtsam.PriorFactorPose3(X(0), initial_state.pose(), priorNoise))
    graph.push_back(
        gtsam.PriorFactorVector(V(0), initial_state.velocity(), velNoise))
    
    graph.push_back(gtsam.PriorFactorConstantBias(B(0), actualBias, gtsam.noiseModel.Isotropic.Sigma(6, 0.1)))

    initial.insert(B(0), actualBias)
    initial.insert(X(0), initial_state.pose())
    initial.insert(V(0), initial_state.velocity())

    isam.update(graph, initial)
    result = isam.calculateEstimate()
    graph = gtsam.NonlinearFactorGraph()
    initial.clear()

    
    return graph, initial, isam, result


graph, initial, isam, result = add_priors(scenario, graph, initial, isam)

# %%
def main_loop(runner, scenario, graph, initial, isam, T, result):
    # The factor index for the estimation rate
    i = 0
    bias_key = B(0)
    PERIOD = 1 # in seconds


    for k, t in enumerate(np.arange(0, T, dt)):
        # get measurements and add them to PIM

        measuredOmega = runner.measuredAngularVelocity(t)
        measuredAcc = runner.measuredSpecificForce(t)

        ### This is where all the magic happens!
        pim.integrateMeasurement(measuredAcc, measuredOmega, dt)

       
        if (k + 1) % int((1 / dt) * PERIOD) == 0:

             # These are additive noise terms (for simulation purposes)
            rotationNoise = gtsam.Rot3.Expmap(np.random.randn(3) * 0.10)
            translationNoise = gtsam.Point3(*np.random.randn(3) * 1)
            poseNoise = gtsam.Pose3(rotationNoise, translationNoise)


            # noisy_state_i = pim.predict(scenario.navState,actualBias)


            if i == 0:
                actual_state_i = scenario.navState(t)
                noisy_state_i = gtsam.NavState(
                actual_state_i.pose().compose(poseNoise),
                actual_state_i.velocity() + np.random.randn(3) * 0.1)

                initial.insert(X(1), noisy_state_i.pose())
                initial.insert(V(1), noisy_state_i.velocity())
            elif i >=2:
                actual_state_i = scenario.navState(t + dt)
                noisy_state_i = gtsam.NavState(
                actual_state_i.pose().compose(poseNoise),
                actual_state_i.velocity() + np.random.randn(3) * 0.1)

                initial.insert(X(i), noisy_state_i.pose())
                initial.insert(V(i), noisy_state_i.velocity())

            if i > 0:

                # Create IMU factor every second.

                # add Bias between factor

                if i % 5 == 0:
                    bias_key += 1
                    initial.insert(bias_key, actualBias)
                    # note that gtsam.imuBias.ConstantBias() defaults to zeroes
                    bias_between_factor = gtsam.BetweenFactorConstantBias(bias_key - 1, bias_key, gtsam.imuBias.ConstantBias(), BIAS_COVARIANCE)
                    graph.add(bias_between_factor)

                    
                # print("bias key: ", bias_key)
                
                factor = gtsam.ImuFactor(X(i - 1), V(i - 1), X(i), V(i), bias_key, pim)
                graph.push_back(factor)

                # We have created the binary constraint, so we clear out the preintegration values.
                pim.resetIntegration()

         
            i += 1


            # print('About to update')

            isam.update(graph, initial)
            result = isam.calculateEstimate()
            graph = gtsam.NonlinearFactorGraph()
            initial.clear()
            

    return graph, result

# %%
plot_scenario(scenario, T, dt, title="Forward Motion", fignum=1)

graph, result = main_loop(runner, scenario, graph, initial, isam, T, result)

print('Result: ', result)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Result:  Values with 53 values:
# Value b0: (gtsam::imuBias::ConstantBias)
# acc = -0.3  0.1  0.2 gyro =      0.1 0.299999     -0.1
#
# Value b1: (gtsam::imuBias::ConstantBias)
# acc = -0.300001       0.1       0.2 gyro = 0.0999882   0.29997      -0.1
#
# Value b2: (gtsam::imuBias::ConstantBias)
# acc = -0.300001       0.1       0.2 gyro = 0.0999849  0.299963 -0.100001
#
# Value b3: (gtsam::imuBias::ConstantBias)
# acc = -0.300001       0.1       0.2 gyro = 0.0999843  0.299963 -0.100001
#
# Value b4: (gtsam::imuBias::ConstantBias)
# acc = -0.300001       0.1       0.2 gyro = 0.0999843  0.299963 -0.100001
#
# Value v0: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2;
# 	4.10053e-10;
# 	1.19814e-09
# ]
#
# Value v1: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.01216;
# 	0.0264163;
# 	-0.000560575
# ]
#
# Value v2: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.03316;
# 	0.0459456;
# 	-0.00130966
# ]
#
# Value v3: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.06591;
# 	0.0651801;
# 	0.000265187
# ]
#
# Value v4: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.1076;
# 	0.081073;
# 	-0.00157844
# ]
#
# Value v5: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.1617;
# 	0.107828;
# 	-0.00141759
# ]
#
# Value v6: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.22524;
# 	0.136793;
# 	-0.00277946
# ]
#
# Value v7: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.29016;
# 	0.162094;
# 	-0.00376125
# ]
#
# Value v8: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.35652;
# 	0.18705;
# 	-0.00318453
# ]
#
# Value v9: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.42735;
# 	0.21949;
# 	-0.00347049
# ]
#
# Value v10: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.51218;
# 	0.252448;
# 	-0.00365969
# ]
#
# Value v11: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.60711;
# 	0.277912;
# 	-0.00156246
# ]
#
# Value v12: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.69833;
# 	0.300586;
# 	0.00166005
# ]
#
# Value v13: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.79747;
# 	0.31782;
# 	0.0020175
# ]
#
# Value v14: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.89013;
# 	0.341301;
# 	0.00368042
# ]
#
# Value v15: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	2.97889;
# 	0.357126;
# 	0.00468373
# ]
#
# Value v16: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	3.07253;
# 	0.375071;
# 	0.00951684
# ]
#
# Value v17: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	3.15375;
# 	0.3887;
# 	0.0139372
# ]
#
# Value v18: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	3.23044;
# 	0.643428;
# 	0.0527973
# ]
#
# Value v19: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	3.43742;
# 	0.673193;
# 	0.216549
# ]
#
# Value v20: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	3.58374;
# 	0.705025;
# 	0.317982
# ]
#
# Value v21: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	3.69793;
# 	0.62418;
# 	0.280515
# ]
#
# Value v22: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	3.80459;
# 	0.524848;
# 	0.41572
# ]
#
# Value v23: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	3.90728;
# 	0.397055;
# 	0.481974
# ]
#
# Value x0: (gtsam::Pose3)
# R: [
# 	1, 2.79567e-10, 1.34813e-07;
# 	-2.79575e-10, 1, 6.08074e-08;
# 	-1.34813e-07, -6.08074e-08, 1
# ]
# t: 1.03379e-10 4.37497e-12 7.35371e-11
#
# Value x1: (gtsam::Pose3)
# R: [
# 	0.999996, -0.00238993, 0.00133846;
# 	0.00238761, 0.999996, 0.00173898;
# 	-0.00134261, -0.00173578, 0.999998
# ]
# t:     4.00394   0.0248812 -0.00148786
#
# Value x2: (gtsam::Pose3)
# R: [
# 	0.99999, -0.00298255, 0.00346903;
# 	0.00297308, 0.999992, 0.00273328;
# 	-0.00347715, -0.00272294, 0.99999
# ]
# t:     6.02523   0.0596687 -0.00225703
#
# Value x3: (gtsam::Pose3)
# R: [
# 	0.99999, -0.00262306, 0.00352012;
# 	0.00261521, 0.999994, 0.00223186;
# 	-0.00352595, -0.00222263, 0.999991
# ]
# t:     8.07432    0.115419 -0.00294804
#
# Value x4: (gtsam::Pose3)
# R: [
# 	0.999982, -0.00364924, 0.0048613;
# 	0.00364037, 0.999992, 0.0018315;
# 	-0.00486794, -0.00181377, 0.999987
# ]
# t:    10.1603    0.18875 -0.0034917
#
# Value x5: (gtsam::Pose3)
# R: [
# 	0.999974, -0.00434454, 0.00581811;
# 	0.00432477, 0.999985, 0.00340766;
# 	-0.00583283, -0.0033824, 0.999977
# ]
# t:     12.2954     0.28159 -0.00491806
#
# Value x6: (gtsam::Pose3)
# R: [
# 	0.999963, -0.00518141, 0.00687098;
# 	0.00516757, 0.999985, 0.00203054;
# 	-0.00688139, -0.00199496, 0.999974
# ]
# t:     14.4883    0.404498 -0.00656063
#
# Value x7: (gtsam::Pose3)
# R: [
# 	0.999966, -0.00561304, 0.00609331;
# 	0.00559601, 0.99998, 0.00280838;
# 	-0.00610896, -0.00277418, 0.999977
# ]
# t:    16.7456   0.552778 -0.0096344
#
# Value x8: (gtsam::Pose3)
# R: [
# 	0.999963, -0.00515537, 0.00688374;
# 	0.00513517, 0.999982, 0.00294823;
# 	-0.00689882, -0.00291277, 0.999972
# ]
# t:    19.0685   0.727972 -0.0132038
#
# Value x9: (gtsam::Pose3)
# R: [
# 	0.999952, -0.00584604, 0.00790236;
# 	0.00582222, 0.999978, 0.00303437;
# 	-0.00791993, -0.00298821, 0.999964
# ]
# t:    21.4606   0.932862 -0.0160489
#
# Value x10: (gtsam::Pose3)
# R: [
# 	0.999945, -0.00445699, 0.00951798;
# 	0.00441846, 0.999982, 0.00406583;
# 	-0.00953593, -0.00402355, 0.999946
# ]
# t:    23.9284    1.16712 -0.0186162
#
# Value x11: (gtsam::Pose3)
# R: [
# 	0.999943, -0.00411323, 0.00982535;
# 	0.00408976, 0.999989, 0.00240734;
# 	-0.00983515, -0.00236702, 0.999949
# ]
# t:     26.487    1.43055 -0.0178836
#
# Value x12: (gtsam::Pose3)
# R: [
# 	0.999945, -0.00309058, 0.010021;
# 	0.00306681, 0.999992, 0.0023865;
# 	-0.0100283, -0.00235564, 0.999947
# ]
# t:    29.1411    1.71595 -0.0164659
#
# Value x13: (gtsam::Pose3)
# R: [
# 	0.999956, -0.00192402, 0.00913689;
# 	0.00190881, 0.999997, 0.00167296;
# 	-0.00914008, -0.00165545, 0.999957
# ]
# t:    31.8963    2.02332 -0.0107237
#
# Value x14: (gtsam::Pose3)
# R: [
# 	0.999951, -0.00202932, 0.00970109;
# 	0.00200778, 0.999995, 0.0022304;
# 	-0.00970557, -0.00221081, 0.99995
# ]
# t:     34.7438     2.35455 -0.00854899
#
# Value x15: (gtsam::Pose3)
# R: [
# 	0.999955, -0.0012345, 0.00944994;
# 	0.00121876, 0.999998, 0.00167106;
# 	-0.00945199, -0.00165947, 0.999954
# ]
# t:    37.6869    2.71468 -0.0155289
#
# Value x16: (gtsam::Pose3)
# R: [
# 	0.999956, -0.00173351, 0.0091981;
# 	0.00171625, 0.999997, 0.00188447;
# 	-0.00920134, -0.0018686, 0.999956
# ]
# t:     40.711    3.09255 -0.0217261
#
# Value x17: (gtsam::Pose3)
# R: [
# 	0.999965, -0.00177081, 0.00815049;
# 	0.00175589, 0.999997, 0.00183694;
# 	-0.00815372, -0.00182256, 0.999965
# ]
# t:   43.8245   3.49455 -0.037206
#
# Value x18: (gtsam::Pose3)
# R: [
# 	0.999963, -0.00288252, 0.00813613;
# 	0.00287354, 0.999995, 0.0011153;
# 	-0.00813931, -0.00109188, 0.999966
# ]
# t:   47.0256   4.46641 0.0466193
#
# Value x19: (gtsam::Pose3)
# R: [
# 	0.999681, -0.00576959, 0.0245876;
# 	0.00579263, 0.999983, -0.000866258;
# 	-0.0245822, 0.00100841, 0.999697
# ]
# t:  50.7817   4.5525 0.885081
#
# Value x20: (gtsam::Pose3)
# R: [
# 	0.999874, -0.0121404, 0.0102211;
# 	0.0122521, 0.999865, -0.0109408;
# 	-0.0100868, 0.0110646, 0.999888
# ]
# t: 54.0949 5.42539 1.57674
#
# Value x21: (gtsam::Pose3)
# R: [
# 	0.999897, -0.0108182, 0.00948187;
# 	0.010934, 0.999865, -0.0122515;
# 	-0.00934805, 0.0123539, 0.99988
# ]
# t: 57.6336 6.41299 1.64006
#
# Value x22: (gtsam::Pose3)
# R: [
# 	0.999861, -0.00963723, 0.0136308;
# 	0.00970773, 0.99994, -0.0051154;
# 	-0.0135807, 0.00524702, 0.999894
# ]
# t:  61.3325  7.06423 0.919988
#
# Value x23: (gtsam::Pose3)
# R: [
# 	0.99969, -0.0201432, 0.0146322;
# 	0.0203676, 0.999675, -0.0153553;
# 	-0.0143181, 0.0156486, 0.999775
# ]
# t: 65.2896 6.93903 3.16475

# %%
def plot_trajectory(values: gtsam.Values,
                    title: str = "Estimated Trajectory",
                    fignum: int = 1,
                    show: bool = False):
    i = 0
    while values.exists(X(i)):
        pose_i = values.atPose3(X(i))
        plot_pose3(fignum, pose_i, 1)
        i += 1
    plt.title(title)

    gtsam.utils.plot.set_axes_equal(fignum)

    plt.ioff()

    if show:
        plt.show()


plot_trajectory(result, title="ISAM Estimate", fignum=2, show=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
scenario = gtsam.ConstantTwistScenario(*scenarios["zero_twist"])
plot_scenario(scenario, T, dt, title="Zero Twist", fignum=3)

runner = gtsam.ScenarioRunner(scenario, pim_params, dt, actualBias)


graph = gtsam.NonlinearFactorGraph()
initial = gtsam.Values()
isam = gtsam.ISAM2()

graph, initial, isam, result = add_priors(scenario, graph, initial, isam)
graph, result = main_loop(runner, scenario, graph, initial, isam, T, result)
plot_trajectory(result, title="ISAM Estimate", fignum=4, show=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
scenario = gtsam.ConstantTwistScenario(*scenarios["loop"])
plot_scenario(scenario, T, dt, title="Loop", fignum=5)

runner = gtsam.ScenarioRunner(scenario, pim_params, dt, actualBias)


graph = gtsam.NonlinearFactorGraph()
initial = gtsam.Values()
isam = gtsam.ISAM2()

graph, initial, isam, result = add_priors(scenario, graph, initial, isam)
graph, result = main_loop(runner, scenario, graph, initial, isam, T, result)
plot_trajectory(result, title="ISAM Estimate", fignum=6, show=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
scenario = gtsam.ConstantTwistScenario(*scenarios["sick"])
plot_scenario(scenario, T, dt, title="Sick", fignum=7)

runner = gtsam.ScenarioRunner(scenario, pim_params, dt, actualBias)


graph = gtsam.NonlinearFactorGraph()
initial = gtsam.Values()
isam = gtsam.ISAM2()

graph, initial, isam, result = add_priors(scenario, graph, initial, isam)
graph, result = main_loop(runner, scenario, graph, initial, isam, T, result)
plot_trajectory(result, title="ISAM Estimate", fignum=8, show=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
